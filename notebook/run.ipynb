# %% [markdown]
# Importing required libraries

# %%
import pca_ranking
import AnerLib
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from collections import defaultdict

# %% [markdown]
# Setting parameters: constants, tranining set and fileName

# %%
#trainingSet = ["mos", "cdc6", "slbp", "prc1", "btg4", "cnot7", "cnot8"]
trainingSet = ['ccnb1', 'tpx2', 'aurka', 'cdc20', 'ccna2']

## nearest neighbors that the algorithm will consider (0 = will consider all genes)
NN = 100
top = 30

#dataset = "examples/Oocyte_datasets.csv"
dataset = "examples/3Cluster_Clean10Mar26.csv"

# %% [markdown]
# Load data and Data scalling

# %%
#Load data
data = pd.read_csv(dataset, index_col=0, header=0)
arr = data

# convert gene index to list
geneIndex = data.index.to_list()

#Data scalling
scaler = StandardScaler()
X_normalized = scaler.fit_transform(arr)

# Getting the index and value of the training set genes
trainingSetIndex = [geneIndex.index(gene) for gene in trainingSet]
trainingSetValue = [arr.iloc[idx] for idx in trainingSetIndex]

# %% [markdown]
# Ranking with PCA strategy: getting closest neighbor of trainingSet using  PCA coordinates

# %%
neighborPCA = pca_ranking.getClosestPCA(top, trainingSetIndex, X_normalized)
topranked = pca_ranking.saveTop(neighborPCA, top, geneIndex, "", "\t")

# %% [markdown]
# Printing the top ranked

# %%
print(topranked)
# Out:
# GeneId,GeneName,smallest distance
# 6860	Mansc1	0.04044228352073082
# 33	abhd17b	0.05766189474989642
# 5729	tbc1d14	0.17654903862970991
# 937	cep55	0.1868523592595975
# 1866	fam168a	0.2323441065234373
# 3524	ndfip2	0.2517685850910869
# 859	cdca8	0.25646680062456806
# 6986	Tmem109	0.28124989231793834
# 6987	Tmem201	0.31210905928044025
# 2744	klhl15	0.3470156342207872
# 4049	phf19	0.34727079762709523
# 4450	psmd3	0.3561165153044346
# 6830	Hnrnpf	0.35826897534473195
# 4660	rbm18	0.3734785689289851
# 3106	med21	0.38205730785689646
# 6218	uba3	0.3906118387985999
# 2855	lin9	0.3962230077417954
# 6859	Mad2l1bp	0.40430881658726653
# 3501	nceh1	0.4193043250332953
# 854	cdca3	0.4334522628482481
# 6750	Ccdc14	0.4357921754873193
# 5577	stard13	0.4367495504718642
# 2397	hirip3	0.440774764839198
# 3371	mthfd2	0.4454865570425864
# 7064	Magohb	0.4455836144276814
# 3183	mier2	0.4463447436018702
# 3954	pdcl3	0.4689549904927799
# 212	alkbh1	0.46939841267651994
# 5105	seh1l	0.47775728771501585
# 5390	smu1	0.480559804039759

# %% [markdown]
# Ranking with ANeR

# %%
 # Aner
G, adj = AnerLib.processGraphAner(arr, trainingSetIndex, geneIndex, 'euclidean', True)
rankMat, rankMat2 = AnerLib.rankingNodes(G, trainingSetIndex)
rankMat.sort(key=lambda k: (k[1], -k[4], k[5], k[2], k[3]), reverse=True)

# %% [markdown]
# Printing top ranked

# %%
topranked = AnerLib.printRank(rankMat,geneIndex,top,"\t")
print(topranked)
# Out:
# GeneId	GeneName	neighbors	cliques	largest clique	mean distance to training set
# 1357	dcun1d5	4	10	4	5.76056492729615
# 5390	smu1	4	10	4	5.923874963703902
# 1027	ckap5	4	12	4	5.92961298874712
# 907	cenpe	4	10	4	6.0822816476073385
# 4550	rab14	4	12	4	6.148047391136495
# 906	cenpa	3	6	3	4.93455972196428
# 859	cdca8	3	8	4	5.053934444033327
# 6039	tra2b	3	6	3	5.171564963266081
# 854	cdca3	3	8	4	5.2467082640644955
# 2431	hnrnph3	3	6	3	5.3561483216300445
# 4345	prc1	3	6	3	5.41231602144325
# 261	anln	3	6	3	5.609028847383922
# 2978	magoh	3	8	4	5.738209977709293
# 951	cetn3	3	8	4	5.886444561907525
# 937	cep55	3	6	3	5.921210866933489
# 2715	kif23	3	8	4	6.020435203478502
# 6635	zcchc8	3	6	3	6.084341529451328
# 2810	lbr	3	8	4	6.350548565661143
# 4226	polr2c	3	8	4	6.598851898879968
# 5160	sfpq	2	3	2	4.807894899959786
# 5551	srsf7	2	4	3	4.840986217425375
# 6534	wsb1	2	4	3	5.081755616668552
# 7008	Troap	2	4	3	5.139836652782758
# 3765	nup35	2	4	3	5.140535186567968
# 2424	hnrnpa2b1	2	4	3	5.156268929578195
# 1799	espl1	2	4	3	5.161600180239118
# 637	brd8	2	3	2	5.1733755134611625
# 3714	nsmce4a	2	4	3	5.205442965619752
# 5515	sptlc1	2	4	3	5.20792317723013
# 6987	Tmem201	2	4	3	5.223974661901817

# %% [markdown]
# Applying Pareto frontiers

# %%
pareto_final = AnerLib.getParetoSet(rankMat2)
list_complet_genes, list_complete = AnerLib.multiObjRanking(pareto_final, rankMat)
topRankedPareto = AnerLib.printFrontPareto(list_complete, geneIndex, trainingSetIndex, top)

print(topRankedPareto)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 pareto_final = AnerLib.getParetoSet(rankMat2)
#       2 list_complet_genes, list_complete = AnerLib.multiObjRanking(pareto_final, rankMat)
# ----> 3 topRankedPareto = Aner.printFrontPareto(list_complete, geneIndex, trainingSetIndex, top)
#       5 print(topRankedPareto)
#
# NameError: name 'Aner' is not defined
